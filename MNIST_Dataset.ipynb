# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharath-Mani/Machine-Learning/blob/main/MNIST_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.datasets import mnist
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Keep only 0s and 1s
train_filter = np.isin(y_train, [0, 1])
test_filter = np.isin(y_test, [0, 1])

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# %%
# Reshape images to 1D vectors
x_train = x_train.reshape((-1, 28*28)).astype('float32') / 255
x_test = x_test.reshape((-1, 28*28)).astype('float32') / 255

# %%
model=LogisticRegression(max_iter=100000)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %%
y_pred=model.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d',cmap="Reds")
plt.show()
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9995271867612293
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       980
#            1       1.00      1.00      1.00      1135
#
#     accuracy                           1.00      2115
#    macro avg       1.00      1.00      1.00      2115
# weighted avg       1.00      1.00      1.00      2115

# %%
for i in range (8):
  plt.imshow(x_test[i].reshape(28,28),cmap="gray")
  plt.title(f"Label:{y_test[i]}, predicted:{y_pred[i]}")
  plt.show()
  print(y_pred[i])
# Out:
# 1
# 0
# 1
# 0
# 0
# 1
# 0
# 0
